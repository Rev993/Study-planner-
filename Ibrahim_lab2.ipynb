# %% [markdown]
# <a href="https://colab.research.google.com/github/Rev993/Study-planner-/blob/main/Ibrahim_lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U google-genai

# %%
from google import genai

# %%
client = genai.Client(api_key="AQ.Ab8RN6JNcJk_n4jj2ck42gstcSyk0TLOFWVH7FbZQFlw2FAEOw")

# %%
MODEL = "models/gemini-3.6-flash"

# %%
response = client.models.generate_content( model="models/gemini-3.6-flash", contents="Hello"

)

print(response.text)
# Out:
# Hello! How can I help you today?

# %%
# !pip install -U google-genai
from google import genai

client = genai.Client(api_key="AQ.Ab8RN6JNcJk_n4jj2ck42gstcSyk0TLOFWVH7FbZQFlw2FAEOw")
MODEL = "models/gemini-3.6-flash"

print("Gemini Chatbot (type 'exit' to quit)\n")

# Chat loop
while True:
    user_input = input("You: ")

    # Exit condition
    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Chatbot: Goodbye 👋")
        break

    # Send input to Gemini
    response = client.models.generate_content(
        model=MODEL,
        contents=user_input
    )
# Out:
# ...
# Gemini Chatbot (type 'exit' to quit)
#
# You: Hello
